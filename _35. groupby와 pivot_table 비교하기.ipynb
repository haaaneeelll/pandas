# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
a1 = ['송중기', '남', 1, 79, 93]
a2 = ['김나현', '여', 1, 85, 85]
a3 = ['권보아', '여', 1, 91, 78]
a4 = ['김범수', '남', 1, 97, 98]
a5 = ['이효리', '여', 2, 93, 79]
a6 = ['박효신', '남', 2, 78, 90]
a7 = ['한예슬', '여', 2, 87, 74]
a8 = ['민경훈', '남', 2, 99, 89]
col1 = ["", "성별", "반", "국어", "영어"]
df1 = pd.DataFrame([a1, a2, a3, a4, a5, a6, a7, a8], columns=col1).set_index("")
df2 = df1.copy()
df2.loc["이효리", "반"] = 1
df2["인원"] = 1
s1 = df1["국어"].copy()

# %%
df1
# Out:
#     성별  반  국어  영어
#
# 송중기  남  1  79  93
# 김나현  여  1  85  85
# 권보아  여  1  91  78
# 김범수  남  1  97  98
# 이효리  여  2  93  79
# 박효신  남  2  78  90
# 한예슬  여  2  87  74
# 민경훈  남  2  99  89

# %% [markdown]
# # 1. 피벗테이블을 groupby처럼 만든다

# %%
df1.groupby(["성별", "반"])[["국어"]].agg("mean").unstack()
# Out:
#       국어
# 반      1     2
# 성별
# 남  88.00 88.50
# 여  88.00 90.00

# %%
df1.pivot_table(["국어"], index =["성별"], columns = "반", aggfunc = "mean")
# Out:
#       국어
# 반      1     2
# 성별
# 남  88.00 88.50
# 여  88.00 90.00

# %% [markdown]
# # 3. Groupby & Agg로 열마다 다른 집계함수

# %%
df2
# Out:
#     성별  반  국어  영어  인원
#
# 송중기  남  1  79  93   1
# 김나현  여  1  85  85   1
# 권보아  여  1  91  78   1
# 김범수  남  1  97  98   1
# 이효리  여  1  93  79   1
# 박효신  남  2  78  90   1
# 한예슬  여  2  87  74   1
# 민경훈  남  2  99  89   1

# %%
df2.groupby(["성별", "반"])[["영어", "인원"]].agg({"영어": "mean", "인원": "count"})
# Out:
#         영어  인원
# 성별 반
# 남  1 95.50   2
#    2 89.50   2
# 여  1 80.67   3
#    2 74.00   1

# %%
df1
# Out:
#     성별  반  국어  영어
#
# 송중기  남  1  79  93
# 김나현  여  1  85  85
# 권보아  여  1  91  78
# 김범수  남  1  97  98
# 이효리  여  2  93  79
# 박효신  남  2  78  90
# 한예슬  여  2  87  74
# 민경훈  남  2  99  89

# %% [markdown]
# # 4. groupby & agg로 lamda 사용한다.

# %%
df1.groupby(["성별", "반"])[["국어", "영어"]].agg(lambda x: x.max() - x.min())
# Out:
#       국어  영어
# 성별 반
# 남  1  18   5
#    2  21   1
# 여  1   6   7
#    2   6   5

# %%
sum(s1 > 80)
df2.groupby(["성별","반"])[["국어","영어"]].agg(lambda x:sum(x>80))
# Out:
#       국어  영어
# 성별 반
# 남  1   1   2
#    2   1   2
# 여  1   3   1
#    2   1   0
