# %%
import pandas as pd
df1= pd.read_excel("/Users/haneul/Desktop/실습/E13EXAMPLE.xlsx" ,sheet_name = 1).set_index("제품")
df2= pd.read_excel("/Users/haneul/Desktop/실습/E13EXAMPLE.xlsx", sheet_name = 2).set_index("제품")

# %%
df3 = df2.sub(df1, fill_value = 0)

# %%
a1 = df3.loc[df3["수량"] != 0]
a1
# Out:
#                  수량
# 제품
# 골드손당면 (300g)  110.0
# 곰돌이 (70g)    -180.0
# 내추럴버블껌 (20g)  -70.0
# 누룽지스낵 (100g)  -60.0
# 들기름 (160mL)  -180.0
# 리얼칩스연근 (30g)   70.0
# 무농약귀리 (500g) -140.0
# 무농약배추 (1입)   -240.0
# 무농약토마토 (2kg)  180.0
# 밀크콘 (160mL)  -280.0
# 베이킹소다 (700g)  100.0
# 부침이두부 (420g) -160.0
# 새우육젓 (1kg)    -70.0
# 새우육젓 (200g)    70.0
# 순수딸기칩 (13g)   160.0
# 신안천일염 (5kg)   -10.0
# 아몬드쿠키 (150g)  -40.0
# 어성초크림 (40g)  -260.0
# 우리백밀가루 (1kg)  100.0
# 우리백밀가루 (2kg)  180.0
# 유기농설탕 (2kg)   -90.0
# 유기농찹쌀 (2kg)  -220.0
# 유기농햅쌀 (4kg)  -270.0
# 유기쌀조청 (480g)  170.0
# 진추어탕 (500g)    70.0
# 찹쌀고추장 (470g) -100.0
# 초코칩쿠키 (125g) -240.0
# 친환경수세미 (2입)  -220.0
# 통째로짜낸사과 (1L) -180.0
